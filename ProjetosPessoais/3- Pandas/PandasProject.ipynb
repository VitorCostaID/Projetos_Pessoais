# %% [markdown]
# ## Projeto para aprender sobre a biblioteca Pandas.

# %%
import pandas as pd
import re

df = pd.read_csv("company_transactions.csv")

print(df.head(3))

# %% [markdown]
# ### Filtros

# %%
## Pegar somente o título das colunas:
# print(df.columns)

## Pegar colunas específicas:
# df['Transaction_Amount']

## Filtrar colunas:
# df.sort_values('Category')
## Pode ser adicionado: 
# df.sort_values(['Category', 'Transaction_ID'], ascending=False)

## Filtrar dados:
#df.loc[df['Payment_Method'] == 'Debit Card']

## Juntando duas condições:
# df.loc[(df['Payment_Method'] == 'Debit Card') | (df['Payment_Method'] == 'Credit Card')]

## Puxando por Palavras:
# df.loc[df['Payment_Method'].str.contains('card|cash', flags=re.I, regex=True)]

# flags=re.I = Permite que não precise começar com maiúsculo.
# regex=True = Permite puxar mais de um valor (card|cash)
# Out:
#        Transaction_ID  Store_ID     Category  Transaction_Amount  Quantity  \
# 0                   1        52  Electronics              482.70         3
# 1                   2        93        Books              221.98         6
# 4                   5        61  Electronics              303.84         2
# 5                   6        21    Groceries               92.59         2
# 8                   9        75   Home Goods              464.66         2
# ...               ...       ...          ...                 ...       ...
# 29991           29992        27    Groceries              284.41         4
# 29995           29996        48        Books              497.62         3
# 29997           29998        81       Sports              275.26         6
# 29998           29999        44     Clothing              307.94         1
# 29999           30000        59   Home Goods              388.36         2
#
#              Date  Customer_Age Payment_Method
# ...

# %% [markdown]
# ### Cálculos

# %%
## Fazer cálculo com dados, Ex:
#df['Transaction_Value'] = df['Transaction_Amount'] / df['Quantity']
#df.head(5)
